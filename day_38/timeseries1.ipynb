# %% [markdown]
# # time series analysis on  the data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df = pd.read_csv('international-airline-passengers.csv')
df.head()
# Out:
#      Month  \
# 0  1949-01
# 1  1949-02
# 2  1949-03
# 3  1949-04
# 4  1949-05
#
#    International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60
# 0                                              112.0
# 1                                              118.0
# 2                                              132.0
# 3                                              129.0
# 4                                              121.0

# %%
df.rename(columns={
    'International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60':'passengers'
},inplace=True)

# %%
df
# Out:
#                                                  Month  passengers
# 0                                              1949-01       112.0
# 1                                              1949-02       118.0
# 2                                              1949-03       132.0
# 3                                              1949-04       129.0
# 4                                              1949-05       121.0
# ..                                                 ...         ...
# 140                                            1960-09       508.0
# 141                                            1960-10       461.0
# 142                                            1960-11       390.0
# 143                                            1960-12       432.0
# 144  International airline passengers: monthly tota...         NaN
#
# [145 rows x 2 columns]

# %%
df.sort_values(by='passengers' , na_position='first')
# Out:
#                                                  Month  passengers
# 144  International airline passengers: monthly tota...         NaN
# 10                                             1949-11       104.0
# 0                                              1949-01       112.0
# 22                                             1950-11       114.0
# 12                                             1950-01       115.0
# ..                                                 ...         ...
# 137                                            1960-06       535.0
# 126                                            1959-07       548.0
# 127                                            1959-08       559.0
# 139                                            1960-08       606.0
# 138                                            1960-07       622.0
#
# [145 rows x 2 columns]

# %%
df.drop(index=[144], inplace=True)

# %%
df
# Out:
#        Month  passengers
# 0    1949-01       112.0
# 1    1949-02       118.0
# 2    1949-03       132.0
# 3    1949-04       129.0
# 4    1949-05       121.0
# ..       ...         ...
# 139  1960-08       606.0
# 140  1960-09       508.0
# 141  1960-10       461.0
# 142  1960-11       390.0
# 143  1960-12       432.0
#
# [144 rows x 2 columns]

# %%
df.passengers = df.passengers.astype(int)

# %%
df =
# Out:
#        Month  passengers
# 0    1949-01         112
# 1    1949-02         118
# 2    1949-03         132
# 3    1949-04         129
# 4    1949-05         121
# ..       ...         ...
# 139  1960-08         606
# 140  1960-09         508
# 141  1960-10         461
# 142  1960-11         390
# 143  1960-12         432
#
# [144 rows x 2 columns]

# %%
df.to_csv('AirlinePassenger.csv')

# %%
# plot this dataset to see trend and seasonality
plt.figure(figsize=[10, 6])
plt.plot(df['Month'],df['passengers'])
plt.xlabel("month")
plt.ylabel("no of passengers")
plt.title("Air passenger data")
plt.show()

# %%
# ploting the same one with seaborn
sns.lineplot(df, x='Month', y='passengers')
# Out:
# <Axes: xlabel='Month', ylabel='passengers'>

# %% [markdown]
# decomposing the data

# %%
# decompose the model into trend seasonality and residuals
decompose = seasonal_decompose(df['passengers'], model='multiplicative', period=12)
decompose.plot()

# %%
trend = decompose.trend.plot()

# %%
residue = decompose.resid
seasonality = decompose.seasonal

# %%
residue
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 139   NaN
# 140   NaN
# 141   NaN
# 142   NaN
# 143   NaN
# Name: resid, Length: 144, dtype: float64

# %%
seasonality
# Out:
# 0      0.910230
# 1      0.883625
# 2      1.007366
# 3      0.975906
# 4      0.981378
#          ...
# 139    1.219911
# 140    1.060492
# 141    0.921757
# 142    0.801178
# 143    0.898824
# Name: seasonal, Length: 144, dtype: float64

# %%
seasonality.plot()
# Out:
# <Axes: >

# %%
df.head()
# Out:
#      Month  passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Load dataset
data = pd.read_csv('AirlinePassenger.csv', parse_dates=['Month'], index_col='Month')

# Visualize data
plt.plot(data['passengers'])
plt.title("Monthly Airline Passengers")
plt.show()

# Normalize data
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(data)

# Prepare training and testing data
train_size = int(len(data_scaled) * 0.8)
train, test = data_scaled[:train_size], data_scaled[train_size:]

def create_dataset(dataset, look_back=1):
    X, y = [], []
    for i in range(len(dataset) - look_back):
        X.append(dataset[i:(i + look_back), 0])
        y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(y)

look_back = 12
X_train, y_train = create_dataset(train, look_back)
X_test, y_test = create_dataset(test, look_back)

# Reshape input to [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Build LSTM model
model = Sequential([
    LSTM(50, return_sequences=False, input_shape=(look_back, 1)),
    Dense(1)
])
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)

# Make predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Inverse transform predictions
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)
y_train = scaler.inverse_transform([y_train])
y_test = scaler.inverse_transform([y_test])

# Plot predictions
plt.plot(data.index, scaler.inverse_transform(data_scaled), label='Actual')
plt.plot(data.index[look_back:look_back + len(train_predict)], train_predict, label='Train Predict')
plt.plot(data.index[len(train_predict) + 2 * look_back:], test_predict, label='Test Predict')
plt.legend()
plt.show()
# Out:
# d:\programs\miniconda3\envs\tf_env\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0858
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0258
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0105
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0055
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.5161e-04
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0010
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9413e-04
# Epoch 11/50
# ...
